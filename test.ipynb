# %%
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread(r'C:\Users\Jemuel\Pictures\Camera Roll\image1.jpg')

# %%
image = cv2.cvtColor(image, cv2.IMREAD_GRAYSCALE)  # OpenCV uses BGR by default
plt.imshow(image)

# %%
image = cv2.resize(image, (96, 96))  # Assuming your model expects 32x32 inputs
plt.imshow(image)
