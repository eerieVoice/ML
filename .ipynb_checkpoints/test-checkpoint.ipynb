# %%
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread(r'C:\Users\Jemuel\Pictures\Camera Roll\wew.jpg')

# %%
image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)  # OpenCV uses BGR by default
plt.imshow(image)

# %%
image = cv2.resize(image, (96, 96))  # Assuming your model expects 32x32 inputs
plt.imshow(image)
